# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from datetime import datetime

# %% [markdown]
# # spotify_data

# %% [markdown]
# This dataset was extracted from the Spotify platform using the Python library "Spotipy", which allows users to access music data provided via APIs. The dataset collected includes about 1 Million tracks with 19 features between 2000 and 2023. Also, there is a total of 61,445 unique artists and 82 genres in the data.
#
# This clean data has been prepared and utilized for research purposes. Its significance lies in its potential to unravel patterns and predict song popularity prior to its release. This dataset could be used to create various predictive models with machine-learning/deep-learning techniques.
#
# https://www.kaggle.com/datasets/amitanshjoshi/spotify-1million-tracks

# %%
pd.set_option('display.max_columns', None)

# %%
spotify = pd.read_csv('reduced_spotify_2022.csv')
spotify.head()
# Out:
#    Unnamed: 0    artist_name           track_name                track_id  \
# 0      530310    Gen Hoshino               Comedy  5SuOikwiRyPMVoIQDJUgSV
# 1      530311  Steve Moakler   Make A Little Room  62yXckrKNy9Sylka6oifst
# 2      530312     Ben Rector          Steady Love  6UOkF086zUgYXnqFxqUvEI
# 3      530313     Ben Rector  Living My Best Life  0R7EWhquaAICmyE5MZqt3q
# 4      530314   Drew Holcomb          Coming Home  2C3gh14oarzTtv3aY3HJ0m
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2022  acoustic         0.676   0.461    1    -6.746     0
# 1          55  2022  acoustic         0.758   0.722    1    -6.252     1
# 2          57  2022  acoustic         0.678   0.277   11   -10.537     1
# 3          56  2022  acoustic         0.566   0.733    4    -5.302     1
# 4          54  2022  acoustic         0.625   0.810   10    -5.995     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1430        0.0322          0.000001     0.358    0.715   87.917
# 1       0.0511        0.1650          0.000006     0.106    0.660  146.031
# 2       0.0602        0.8430          0.000004     0.104    0.238   76.935
# 3       0.0699        0.0830          0.000002     0.362    0.636  178.828
# 4       0.0330        0.1460          0.000027     0.135    0.741  104.066
#
#    duration_ms  time_signature
# 0       230667               4
# 1       180493               4
# 2       224333               4
# 3       215213               4
# 4       146360               4

# %%
spotify.shape
# Out:
# (53692, 20)

# %%
spotify.isna().sum()
# Out:
# Unnamed: 0          0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# year                0
# genre               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# # 1. Preprocessing

# %%
grouped_df = spotify.groupby('artist_name')['track_name'].apply(list).reset_index()
grouped_df.shape
# Out:
# (12779, 2)

# %%
#created a new encoded column that identifies each singer 
#motive, maybe if a singer is know it'll have more popularity
spotify['artist_label'] = pd.factorize(spotify['artist_name'])[0]
spotify['artist_label'].describe()
# Out:
# count    53692.000000
# mean      6201.992755
# std       3747.952493
# min          0.000000
# 25%       2739.000000
# 50%       6378.000000
# 75%       9597.250000
# max      12778.000000
# Name: artist_label, dtype: float64

# %%
#Maybe the shorter the name better popularity
# Create a new column 'word_count' with the total word count for each track name

def count_word(text):
    return len(text.split())


spotify['word_count_track123'] = spotify['track_name'].apply(count_word)
spotify['word_count_track123'].describe()
# Out:
# count    53692.000000
# mean         3.465749
# std          2.617360
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         40.000000
# Name: word_count_track123, dtype: float64

# %%
#Maybe the shorter the name better popularity
# Create a new column 'word_count_track' with the total word count for each track name

def word_count(data, text_column_name):
    data['word_count_track'] = data[text_column_name].apply(lambda text: len(text.split()))
    return data

word_count(spotify, 'track_name')
# Out:
#        Unnamed: 0       artist_name  \
# 0          530310       Gen Hoshino
# 1          530311     Steve Moakler
# 2          530312        Ben Rector
# 3          530313        Ben Rector
# 4          530314      Drew Holcomb
# ...           ...               ...
# 53687      583997       Ursula 1000
# 53688      583998         Morcheeba
# 53689      583999         Morcheeba
# 53690      584000  Jay-Jay Johanson
# 53691      584001       Ursula 1000
#
#                                              track_name  \
# 0                                                Comedy
# 1                                    Make A Little Room
# 2                                           Steady Love
# 3                                   Living My Best Life
# 4                                           Coming Home
# ...                                                 ...
# 53687                              Don't Cheat The Beat
# 53688  What New York Couples Fight About - Instrumental
# 53689                         Way Beyond - Instrumental
# 53690             Both sides now - From "Love Actually"
# 53691                 Kinda' Kinky - A.Skillz Dub Remix
#
#                      track_id  popularity  year     genre  danceability  \
# 0      5SuOikwiRyPMVoIQDJUgSV          68  2022  acoustic         0.676
# 1      62yXckrKNy9Sylka6oifst          55  2022  acoustic         0.758
# 2      6UOkF086zUgYXnqFxqUvEI          57  2022  acoustic         0.678
# 3      0R7EWhquaAICmyE5MZqt3q          56  2022  acoustic         0.566
# 4      2C3gh14oarzTtv3aY3HJ0m          54  2022  acoustic         0.625
# ...                       ...         ...   ...       ...           ...
# 53687  4pmoZnemYFd8r0Hoet7bTe           1  2022  trip-hop         0.696
# 53688  2z73p5IpvIxuLkyRCo7inP           0  2022  trip-hop         0.667
# 53689  3oOztziCNDx8fPmkZePB0u           0  2022  trip-hop         0.630
# 53690  3jyWKT91FkQYijWGCMAF0h           9  2022  trip-hop         0.331
# 53691  3HiIvz2vtTwLzDQYmwv6QN           0  2022  trip-hop         0.826
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0       0.461    1    -6.746     0       0.1430       0.03220
# 1       0.722    1    -6.252     1       0.0511       0.16500
# 2       0.277   11   -10.537     1       0.0602       0.84300
# 3       0.733    4    -5.302     1       0.0699       0.08300
# 4       0.810   10    -5.995     1       0.0330       0.14600
# ...       ...  ...       ...   ...          ...           ...
# 53687   0.806    4    -6.447     0       0.0347       0.01190
# 53688   0.634    2   -10.974     1       0.0275       0.37600
# 53689   0.472    7    -9.448     1       0.0310       0.00779
# 53690   0.280   11   -10.733     1       0.0360       0.69800
# 53691   0.933    2    -6.979     1       0.1050       0.01820
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 0              0.000001    0.3580    0.715   87.917       230667
# 1              0.000006    0.1060    0.660  146.031       180493
# 2              0.000004    0.1040    0.238   76.935       224333
# 3              0.000002    0.3620    0.636  178.828       215213
# 4              0.000027    0.1350    0.741  104.066       146360
# ...                 ...       ...      ...      ...          ...
# 53687          0.013100    0.0708    0.963  120.015       251803
# 53688          0.648000    0.1020    0.412  155.991       375667
# 53689          0.802000    0.1300    0.379   81.001       216507
# 53690          0.004090    0.1910    0.263   73.156       270187
# 53691          0.656000    0.3800    0.879  120.028       214364
#
#        time_signature  artist_label  word_count_track123  word_count_track
# 0                   4             0                    1                 1
# 1                   4             1                    4                 4
# 2                   4             2                    2                 2
# 3                   4             2                    4                 4
# 4                   4             3                    2                 2
# ...               ...           ...                  ...               ...
# 53687               4         12762                    4                 4
# 53688               4         12711                    8                 8
# 53689               4         12711                    4                 4
# 53690               5         12737                    7                 7
# 53691               4         12762                    6                 6
#
# [53692 rows x 23 columns]

# %%
def labelencoder(df: pd.DataFrame, column:str) -> pd.DataFrame:
    if isinstance(column, str):  # If a single column name is provided
        column = [column]  # Convert it to a list

        missing_columns = [col for col in column if col not in df]
        if missing_columns:
            raise ValueError(f"Columns {missing_columns} not found in the DataFrame.")
        
    encoder = LabelEncoder()
    spotify[f'{column}_encoded'] = encoder.fit_transform(df[column])
    return df

labelencoder(spotify, 'genre')
# Out:
# c:\Users\arimi\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#        Unnamed: 0       artist_name  \
# 0          530310       Gen Hoshino
# 1          530311     Steve Moakler
# 2          530312        Ben Rector
# 3          530313        Ben Rector
# 4          530314      Drew Holcomb
# ...           ...               ...
# 53687      583997       Ursula 1000
# 53688      583998         Morcheeba
# 53689      583999         Morcheeba
# 53690      584000  Jay-Jay Johanson
# 53691      584001       Ursula 1000
#
#                                              track_name  \
# 0                                                Comedy
# 1                                    Make A Little Room
# 2                                           Steady Love
# 3                                   Living My Best Life
# 4                                           Coming Home
# ...                                                 ...
# 53687                              Don't Cheat The Beat
# 53688  What New York Couples Fight About - Instrumental
# 53689                         Way Beyond - Instrumental
# 53690             Both sides now - From "Love Actually"
# 53691                 Kinda' Kinky - A.Skillz Dub Remix
#
#                      track_id  popularity  year     genre  danceability  \
# 0      5SuOikwiRyPMVoIQDJUgSV          68  2022  acoustic         0.676
# 1      62yXckrKNy9Sylka6oifst          55  2022  acoustic         0.758
# 2      6UOkF086zUgYXnqFxqUvEI          57  2022  acoustic         0.678
# 3      0R7EWhquaAICmyE5MZqt3q          56  2022  acoustic         0.566
# 4      2C3gh14oarzTtv3aY3HJ0m          54  2022  acoustic         0.625
# ...                       ...         ...   ...       ...           ...
# 53687  4pmoZnemYFd8r0Hoet7bTe           1  2022  trip-hop         0.696
# 53688  2z73p5IpvIxuLkyRCo7inP           0  2022  trip-hop         0.667
# 53689  3oOztziCNDx8fPmkZePB0u           0  2022  trip-hop         0.630
# 53690  3jyWKT91FkQYijWGCMAF0h           9  2022  trip-hop         0.331
# 53691  3HiIvz2vtTwLzDQYmwv6QN           0  2022  trip-hop         0.826
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0       0.461    1    -6.746     0       0.1430       0.03220
# 1       0.722    1    -6.252     1       0.0511       0.16500
# 2       0.277   11   -10.537     1       0.0602       0.84300
# 3       0.733    4    -5.302     1       0.0699       0.08300
# 4       0.810   10    -5.995     1       0.0330       0.14600
# ...       ...  ...       ...   ...          ...           ...
# 53687   0.806    4    -6.447     0       0.0347       0.01190
# 53688   0.634    2   -10.974     1       0.0275       0.37600
# 53689   0.472    7    -9.448     1       0.0310       0.00779
# 53690   0.280   11   -10.733     1       0.0360       0.69800
# 53691   0.933    2    -6.979     1       0.1050       0.01820
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 0              0.000001    0.3580    0.715   87.917       230667
# 1              0.000006    0.1060    0.660  146.031       180493
# 2              0.000004    0.1040    0.238   76.935       224333
# 3              0.000002    0.3620    0.636  178.828       215213
# 4              0.000027    0.1350    0.741  104.066       146360
# ...                 ...       ...      ...      ...          ...
# 53687          0.013100    0.0708    0.963  120.015       251803
# 53688          0.648000    0.1020    0.412  155.991       375667
# 53689          0.802000    0.1300    0.379   81.001       216507
# 53690          0.004090    0.1910    0.263   73.156       270187
# 53691          0.656000    0.3800    0.879  120.028       214364
#
#        time_signature  artist_label  word_count_track123  word_count_track  \
# 0                   4             0                    1                 1
# 1                   4             1                    4                 4
# 2                   4             2                    2                 2
# 3                   4             2                    4                 4
# 4                   4             3                    2                 2
# ...               ...           ...                  ...               ...
# 53687               4         12762                    4                 4
# 53688               4         12711                    8                 8
# 53689               4         12711                    4                 4
# 53690               5         12737                    7                 7
# 53691               4         12762                    6                 6
#
#        ['genre']_encoded
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 53687                 81
# 53688                 81
# 53689                 81
# 53690                 81
# 53691                 81
#
# [53692 rows x 24 columns]

# %%
print(spotify['genre'].nunique())
encoder = LabelEncoder()
spotify['genre_encoded'] = encoder.fit_transform(spotify['genre'])
# Out:
# 82

# %%
spotify['years_since_out'] = datetime.today().year - spotify.year 
# Print the result
print(spotify[['year', 'years_since_out']].head())
# Out:
#    year  years_since_out
# 0  2022                1
# 1  2022                1
# 2  2022                1
# 3  2022                1
# 4  2022                1

# %%
#Also drop the ones I don't think apport any value
columns1 = ['track_id', 'Unnamed: 0']
spotify = spotify.drop(columns1, axis=1)

# %%
spotify.describe()
# Out:
#          popularity     year  danceability        energy          key  \
# count  53692.000000  53692.0  53692.000000  53692.000000  53692.00000
# mean      31.088970   2022.0      0.548411      0.641324      5.26937
# std       17.848236      0.0      0.181508      0.274144      3.56453
# min        0.000000   2022.0      0.054200      0.000056      0.00000
# 25%       17.000000   2022.0      0.430750      0.462000      2.00000
# 50%       31.000000   2022.0      0.564000      0.702000      5.00000
# 75%       44.000000   2022.0      0.685000      0.873000      8.00000
# max       94.000000   2022.0      0.985000      1.000000     11.00000
#
#            loudness          mode   speechiness  acousticness  \
# count  53692.000000  53692.000000  53692.000000   53692.00000
# mean      -8.962979      0.617839      0.098261       0.31657
# std        6.237880      0.485920      0.135566       0.35344
# min      -47.322000      0.000000      0.022200       0.00000
# 25%      -10.458000      0.000000      0.038400       0.00734
# 50%       -7.185000      1.000000      0.052100       0.14300
# 75%       -5.131000      1.000000      0.092800       0.61800
# max        2.820000      1.000000      0.962000       0.99600
#
#        instrumentalness      liveness       valence         tempo  \
# count      53692.000000  53692.000000  53692.000000  53692.000000
# mean           0.250889      0.217718      0.425979    122.101232
# std            0.366219      0.192361      0.258060     30.035130
# min            0.000000      0.009950      0.000000     31.237000
# 25%            0.000000      0.100000      0.207000     99.605750
# 50%            0.001330      0.131000      0.401000    123.002000
# 75%            0.609000      0.284000      0.626000    140.038000
# max            1.000000      0.998000      0.995000    229.949000
#
#         duration_ms  time_signature  artist_label  word_count_track123  \
# count  5.369200e+04    53692.000000  53692.000000         53692.000000
# mean   2.165807e+05        3.893727   6201.992755             3.465749
# std    1.050098e+05        0.454595   3747.952493             2.617360
# min    1.555900e+04        0.000000      0.000000             1.000000
# 25%    1.616668e+05        4.000000   2739.000000             2.000000
# 50%    2.000000e+05        4.000000   6378.000000             3.000000
# 75%    2.493645e+05        4.000000   9597.250000             4.000000
# max    4.318932e+06        5.000000  12778.000000            40.000000
#
#        word_count_track  ['genre']_encoded  genre_encoded  years_since_out
# count      53692.000000       53692.000000   53692.000000          53692.0
# mean           3.465749          38.001062      38.001062              1.0
# std            2.617360          23.780676      23.780676              0.0
# min            1.000000           0.000000       0.000000              1.0
# 25%            2.000000          16.000000      16.000000              1.0
# 50%            3.000000          38.000000      38.000000              1.0
# 75%            4.000000          58.000000      58.000000              1.0
# max           40.000000          81.000000      81.000000              1.0

# %% [markdown]
# # 2. Feature creation

# %%
def create_binary_energy_column(data, column_name, threshold=0.5):
    data['is_' + column_name + '_high'] = (data[column_name] > threshold).astype(int)
    return data


# Call the function to create a categorical bin column for 'energy'
spotify = create_binary_energy_column(spotify, 'energy', threshold=0.5)
spotify = create_binary_energy_column(spotify, 'loudness', threshold=-10) 
spotify.head()
# Out:
#      artist_name           track_name  popularity  year     genre  \
# 0    Gen Hoshino               Comedy          68  2022  acoustic
# 1  Steve Moakler   Make A Little Room          55  2022  acoustic
# 2     Ben Rector          Steady Love          57  2022  acoustic
# 3     Ben Rector  Living My Best Life          56  2022  acoustic
# 4   Drew Holcomb          Coming Home          54  2022  acoustic
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676   0.461    1    -6.746     0       0.1430        0.0322
# 1         0.758   0.722    1    -6.252     1       0.0511        0.1650
# 2         0.678   0.277   11   -10.537     1       0.0602        0.8430
# 3         0.566   0.733    4    -5.302     1       0.0699        0.0830
# 4         0.625   0.810   10    -5.995     1       0.0330        0.1460
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000001     0.358    0.715   87.917       230667               4
# 1          0.000006     0.106    0.660  146.031       180493               4
# 2          0.000004     0.104    0.238   76.935       224333               4
# 3          0.000002     0.362    0.636  178.828       215213               4
# 4          0.000027     0.135    0.741  104.066       146360               4
#
#    artist_label  word_count_track123  word_count_track  ['genre']_encoded  \
# 0             0                    1                 1                  0
# 1             1                    4                 4                  0
# 2             2                    2                 2                  0
# 3             2                    4                 4                  0
# 4             3                    2                 2                  0
#
#    genre_encoded  years_since_out energy_category loudness_category  \
# 0              0                1      low_energy              loud
# 1              0                1     high_energy              loud
# 2              0                1      low_energy              soft
# 3              0                1     high_energy              loud
# 4              0                1     high_energy              loud
#
#    party_song  energy_binary  loudness_binary
# 0           0              0                1
# 1           0              1                1
# 2           0              0                0
# 3           0              1                1
# 4           0              1                1

# %%
def create_categorical_bin(data, column_name, bins, labels):
    data[column_name + '_category'] = pd.cut(data[column_name], bins=bins, labels=labels)
    return data

spotify = create_categorical_bin(spotify, 'energy', bins=[0, 0.5, 1], labels=['low', 'high'])
spotify = create_categorical_bin(spotify, 'loudness', bins=[-60, -10, 3], labels=['soft', 'loud'])

# %%
spotify['energy_category'] = pd.cut(spotify['energy'], bins=[0, 0.5, 1], labels=['low_energy', 'high_energy'])
spotify['loudness_category'] = pd.cut(spotify['loudness'], bins=[-60, -10, 3], labels=['soft', 'loud'])

# %%
spotify['party_song'] = ((spotify['danceability'] > 0.5) & (spotify['energy'] > 0.5) & (spotify['loudness'] < -10) & (spotify['liveness'] > 0.5))
spotify['party_song'] = encoder.fit_transform(spotify['party_song'])
spotify['party_song'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: party_song, dtype: int64

# %%
def add_sleep_music_column(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add a binary variable column 'sleep_music' to a DataFrame based on specified conditions

    Args:
        df (pd.DataFrame): The DataFrame containing columns 'instrumentalness', 'duration_minutes', and 'energy'

    Returns:
        pd.DataFrame: The DataFrame with an added 'sleep_music' column
    """
    conditions = (df['instrumentalness'] > 0.6) & (df['duration_minutes'] > 5) & (df['energy'] < 0.5)

    # Add a binary variable column 'party_music' based on the specified conditions
    df['sleep_music'] = conditions.astype(int)

    return df

# %%
print(spotify['party_song'].nunique())
# Out:
# 2

# %% [markdown]
# # 3. Split or cross validation

# %% [markdown]
# # 4. Train model and generate predictions

# %% [markdown]
# # 5. Hyperparameter tuning and choose the best set of hyperparameters.

# %% [markdown]
# # 6.Model’s performance on a set of metrics.
